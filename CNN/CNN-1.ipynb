# %% [markdown]
# # 2020 Fall Final Project code1 (CNN Model 1st Try)

# %% [markdown]
# ## Data Preprocessing

# %%
import os
import random
from shutil import copy2

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %%
print('number of A:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/A')))
print('number of B:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/B')))
print('number of E:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/E')))
print('number of G:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/G')))
# Out:
# number of A: 375
# number of B: 948
# number of E: 808
# number of G: 608

# %%
base_dir = '/Users/yixuanwang/Desktop/2020 F Final_Project'

# %%
train_dir = os.path.join(base_dir, 'train')
if not os.path.exists(train_dir):
    os.mkdir(train_dir)
    
validation_dir = os.path.join(base_dir, 'validation')
if not os.path.exists(validation_dir):
    os.mkdir(validation_dir)
    
test_dir = os.path.join(base_dir, 'test')
if not os.path.exists(test_dir):
    os.mkdir(test_dir)

# %%
train_a_dir = os.path.join(train_dir, 'A')
if not os.path.exists(train_a_dir):
    os.mkdir(train_a_dir)
train_b_dir = os.path.join(train_dir, 'B')
if not os.path.exists(train_b_dir):
    os.mkdir(train_b_dir)
train_e_dir = os.path.join(train_dir, 'E')
if not os.path.exists(train_e_dir):
    os.mkdir(train_e_dir)
train_g_dir = os.path.join(train_dir, 'G')
if not os.path.exists(train_g_dir):
    os.mkdir(train_g_dir)

# %%
test_a_dir = os.path.join(test_dir, 'A')
if not os.path.exists(test_a_dir):
    os.mkdir(test_a_dir)
test_b_dir = os.path.join(test_dir, 'B')
if not os.path.exists(test_b_dir):
    os.mkdir(test_b_dir)
test_e_dir = os.path.join(test_dir, 'E')
if not os.path.exists(test_e_dir):
    os.mkdir(test_e_dir)
test_g_dir = os.path.join(test_dir, 'G')
if not os.path.exists(test_g_dir):
    os.mkdir(test_g_dir)

# %%
validation_a_dir = os.path.join(validation_dir, 'A')
if not os.path.exists(validation_a_dir):
    os.mkdir(validation_a_dir)
validation_b_dir = os.path.join(validation_dir, 'B')
if not os.path.exists(validation_b_dir):
    os.mkdir(validation_b_dir)
validation_e_dir = os.path.join(validation_dir, 'E')
if not os.path.exists(validation_e_dir):
    os.mkdir(validation_e_dir)
validation_g_dir = os.path.join(validation_dir, 'G')
if not os.path.exists(validation_g_dir):
    os.mkdir(validation_g_dir)

# %%
A_dir = '/Users/yixuanwang/Desktop/2020 F Final_Project/A'
B_dir = '/Users/yixuanwang/Desktop/2020 F Final_Project/B'
E_dir = '/Users/yixuanwang/Desktop/2020 F Final_Project/E'
G_dir = '/Users/yixuanwang/Desktop/2020 F Final_Project/G'

# %%
num_A = len(os.listdir(A_dir))
num_B = len(os.listdir(B_dir))
num_E = len(os.listdir(E_dir))
num_G = len(os.listdir(G_dir))

# %%
A_all = os.listdir(A_dir)
B_all = os.listdir(B_dir)
E_all = os.listdir(E_dir)
G_all = os.listdir(G_dir)

# %%
index_list_a = list(range(num_A))
index_list_b = list(range(num_B))
index_list_e = list(range(num_E))
index_list_g = list(range(num_G))

# %%
random.shuffle(index_list_a)
random.shuffle(index_list_b)
random.shuffle(index_list_e)
random.shuffle(index_list_g)

# %%
num = 0

# %%
for i in index_list_a:
    fileName = os.path.join(A_dir, A_all[i])
    if num < num_A*0.6:
        print(str(fileName))
        copy2(fileName, train_a_dir)
    elif num > num_A *0.6 and num < num_A*0.8:
        copy2(fileName, test_a_dir)
    else:
        copy2(fileName, validation_a_dir)
    num += 1
# Out:
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-45.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-22 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-22 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-60 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-53.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-24 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-05 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-20.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-17 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-16.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-05.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-31.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-23 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-24.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-43 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-11 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-47 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-35.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-13 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-20 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-41 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-54.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-08 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-21 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-58 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-23 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-15 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-52 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-51 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-57.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-24 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-54 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-08 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-22 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-14 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-11 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-17 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-21 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-24 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-38.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-13.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-1 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-18.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-06 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-48 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-14 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-61.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-30 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-32.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-43.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-17 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-11.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-39 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-21 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-14.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-46 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-23 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-20 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-06.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-51.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-22.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-16 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-06 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-55.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-21 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-55 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-11 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-63 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-37.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-29 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-11 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-06 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-45 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-28 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-15 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-14 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-64 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-24 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-1 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-21 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-52.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-59.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-50.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-56.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-18 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-05 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-05 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-15 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-18 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-18 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-40 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-61 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-38 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-60.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-06 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-05 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-05 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-23 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-20 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-18 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-16 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-11 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-18 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-41.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-24 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-62 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-08 (11).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-34.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-17 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-16 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-09 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-02 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-15 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-44.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-56 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-53 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-13 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-34 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-22 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-01 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (10).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-19 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-04 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-25 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-14 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-10 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-32 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-07 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-12 (9).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-13 (7).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-26 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-1 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-40.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-06 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-23 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-57 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-27 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-03 (8).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/A/1-20 (8).jpg

# %%
for i in index_list_b:
    fileName = os.path.join(B_dir, B_all[i])
    if num < num_B*0.6:
        print(str(fileName))
        copy2(fileName, train_b_dir)
    elif num > num_B *0.6 and num < num_B*0.8:
        copy2(fileName, test_b_dir)
    else:
        copy2(fileName, validation_b_dir)
    num += 1
# Out:
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-04 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-027.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-23 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-002 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-016.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-042 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-027 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-035 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-012.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-023 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-54 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-028.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-033 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-038 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-30 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-019.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-002 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-018 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-034 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-20 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-048 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-055 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-04 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-048 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-14 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-29 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-49 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-015 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-021 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-012 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-030 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-038 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-008 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-031.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-001 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-29 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-005 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-025 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-002 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-042 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-012.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-005 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-13 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-027.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-31.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-015.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-023.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-34 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-49 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-036.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-025 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-41 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-01 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-08 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-002 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-035.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-056 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-51.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-004.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-026 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-043 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-017.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-018 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-16 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-018 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-004 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-022 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-038 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-007 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-006.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-23 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-016 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-014.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-032 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-021 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-053.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-35.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-054.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-12 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-036 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-47 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-038.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-027 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-034 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-13 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-025 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-10 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-015.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-026 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-012.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-032.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-032 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-036.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-025.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-021 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-20.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-043 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-033 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-25 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-38 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-27 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-34 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-011.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-23 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-019 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-019 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-20 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-015 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-041 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-003.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-04.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-009 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-032.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-46 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-24.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-11 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-14.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-47.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-027 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-07 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-31 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-27 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-012 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-48 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-025 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-05 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-10 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-26 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-032 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-45 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-046.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-32 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-017.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-047 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-012 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-43.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-048 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-029 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-029.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-016 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-045 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-17.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-27 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-045 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-26 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-019 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-041 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-009 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-24 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-041.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-001.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-036 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-009.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-007 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-020 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-030 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-019.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-23 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-012 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-024.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-029 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-015 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-018 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-026.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-020 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-049.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-039.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-052.jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-09 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-047 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-19 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-003 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-011 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-47 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-017 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-017 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-24 (6).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-005 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-014 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-026 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-026 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-003 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-50 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-018 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-20 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-033 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-041 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-23 (5).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-048 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-44 (3).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/3-038 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-034 (2).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/1-15 (4).jpg
# /Users/yixuanwang/Desktop/2020 F Final_Project/B/2-042 (4).jpg

# %%
for i in index_list_e:
    fileName = os.path.join(E_dir, E_all[i])
    if num < num_E*0.6:
        print(str(fileName))
        copy2(fileName, train_e_dir)
    elif num > num_E *0.6 and num < num_E*0.8:
        copy2(fileName, test_e_dir)
    else:
        copy2(fileName, validation_e_dir)
    num += 1

# %%
for i in index_list_g:
    fileName = os.path.join(G_dir, G_all[i])
    if num < num_G*0.6:
        print(str(fileName))
        copy2(fileName, train_g_dir)
    elif num > num_G *0.6 and num < num_G*0.8:
        copy2(fileName, test_g_dir)
    else:
        copy2(fileName, validation_g_dir)
    num += 1

# %%
print('number of training a:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/train/A')))
print('number of training b:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/train/B')))
print('number of training e:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/train/E')))
print('number of training g:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/train/G')))
# Out:
# number of training a: 369
# number of training b: 579
# number of training e: 485
# number of training g: 365

# %%
print('number of testing a:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/test/A')))
print('number of testing b:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/test/B')))
print('number of testing e:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/test/E')))
print('number of testing g:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/test/G')))
# Out:
# number of testing a: 214
# number of testing b: 540
# number of testing e: 162
# number of testing g: 122

# %%
print('number of validation a:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/validation/A')))
print('number of validation b:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/validation/B')))
print('number of validation e:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/validation/E')))
print('number of validation g:',len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/validation/G')))
# Out:
# number of validation a: 224
# number of validation b: 929
# number of validation e: 808
# number of validation g: 608

# %%
from keras.preprocessing.image import ImageDataGenerator
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        '/Users/yixuanwang/Desktop/2020 F Final_Project/train',
        batch_size=32,
        class_mode='categorical',
        color_mode = 'grayscale')
# Out:
# Found 1798 images belonging to 4 classes.

# %%
test_generator = train_datagen.flow_from_directory(
        '/Users/yixuanwang/Desktop/2020 F Final_Project/test',
        batch_size=32,
        class_mode='categorical',
        color_mode = 'grayscale')
# Out:
# Found 1038 images belonging to 4 classes.

# %%
validation_generator = train_datagen.flow_from_directory(
        '/Users/yixuanwang/Desktop/2020 F Final_Project/validation',
        batch_size=32,
        class_mode='categorical',
        color_mode = 'grayscale')
# Out:
# Found 2569 images belonging to 4 classes.

# %%
for data_batch, labels_batch in train_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (32, 256, 256, 1)
# labels batch shape: (32, 4)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.subplot(3,3,1)
plt.imshow(data_batch[5].reshape(256,256),cmap='gray')
plt.subplot(3,3,2)
plt.imshow(data_batch[10].reshape(256,256),cmap='gray')
plt.subplot(3,3,3)
plt.imshow(data_batch[15].reshape(256,256),cmap='gray')
plt.subplot(3,3,4)
plt.imshow(data_batch[20].reshape(256,256),cmap='gray')
plt.subplot(3,3,5)
plt.imshow(data_batch[1].reshape(256,256),cmap='gray')
plt.subplot(3,3,6)
plt.imshow(data_batch[6].reshape(256,256),cmap='gray')
plt.subplot(3,3,7)
plt.imshow(data_batch[9].reshape(256,256),cmap='gray')
plt.subplot(3,3,8)
plt.imshow(data_batch[14].reshape(256,256),cmap='gray')
plt.subplot(3,3,9)
plt.imshow(data_batch[21].reshape(256,256),cmap='gray')
plt.show()

# %% [markdown]
# ## CNN

# %%
from keras import layers
from keras import models
from keras.layers.core import Dropout
from IPython.display import Image
from keras.utils.vis_utils import model_to_dot

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(256, 256, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.25))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 32)      320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 64)      18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 13,087,876
# Trainable params: 13,087,876
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
G = model_to_dot (model)
Image (G.create (prog = "dot", format = "jpg"))

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=50,
      epochs=20,
      validation_data=validation_generator,
      validation_steps=50)
# Out:
# Epoch 1/20
# 50/50 [==============================] - 146s 3s/step - loss: 0.9670 - acc: 0.6079 - val_loss: 0.4238 - val_acc: 0.8169
# Epoch 2/20
# 50/50 [==============================] - 155s 3s/step - loss: 0.3174 - acc: 0.8992 - val_loss: 0.1066 - val_acc: 0.9746
# Epoch 3/20
# 50/50 [==============================] - 160s 3s/step - loss: 0.1363 - acc: 0.9515 - val_loss: 0.0339 - val_acc: 0.9905
# Epoch 4/20
# 50/50 [==============================] - 149s 3s/step - loss: 0.0725 - acc: 0.9767 - val_loss: 0.0316 - val_acc: 0.9987
# Epoch 5/20
# 50/50 [==============================] - 136s 3s/step - loss: 0.0244 - acc: 0.9950 - val_loss: 0.0172 - val_acc: 0.9994
# Epoch 6/20
# 50/50 [==============================] - 131s 3s/step - loss: 0.0260 - acc: 0.9930 - val_loss: 0.0024 - val_acc: 0.9987
# Epoch 7/20
# 50/50 [==============================] - 134s 3s/step - loss: 0.0113 - acc: 0.9969 - val_loss: 0.0017 - val_acc: 0.9994
# Epoch 8/20
# 50/50 [==============================] - 131s 3s/step - loss: 0.0081 - acc: 0.9975 - val_loss: 0.0068 - val_acc: 0.9975
# Epoch 9/20
# 50/50 [==============================] - 131s 3s/step - loss: 9.2229e-04 - acc: 1.0000 - val_loss: 0.0036 - val_acc: 0.9994
# Epoch 10/20
# 50/50 [==============================] - 128s 3s/step - loss: 8.5994e-04 - acc: 1.0000 - val_loss: 0.0038 - val_acc: 0.9975
# Epoch 11/20
# 50/50 [==============================] - 129s 3s/step - loss: 0.0088 - acc: 0.9962 - val_loss: 9.0095e-04 - val_acc: 0.9994
# Epoch 12/20
# 50/50 [==============================] - 130s 3s/step - loss: 0.0012 - acc: 1.0000 - val_loss: 3.0476e-04 - val_acc: 1.0000
# Epoch 13/20
# 50/50 [==============================] - 129s 3s/step - loss: 1.3678e-04 - acc: 1.0000 - val_loss: 8.5682e-07 - val_acc: 0.9994
# Epoch 14/20
# 50/50 [==============================] - 130s 3s/step - loss: 0.0039 - acc: 0.9994 - val_loss: 0.0154 - val_acc: 0.9862
# Epoch 15/20
# 50/50 [==============================] - 128s 3s/step - loss: 0.0064 - acc: 0.9981 - val_loss: 7.4321e-05 - val_acc: 0.9987
# Epoch 16/20
# 50/50 [==============================] - 130s 3s/step - loss: 7.6879e-04 - acc: 0.9994 - val_loss: 5.1415e-05 - val_acc: 1.0000
# Epoch 17/20
# 50/50 [==============================] - 129s 3s/step - loss: 6.4143e-05 - acc: 1.0000 - val_loss: 7.4398e-04 - val_acc: 0.9994
# Epoch 18/20
# 50/50 [==============================] - 129s 3s/step - loss: 0.0042 - acc: 0.9987 - val_loss: 1.2179e-05 - val_acc: 0.9994
# Epoch 19/20
# 50/50 [==============================] - 127s 3s/step - loss: 4.0128e-05 - acc: 1.0000 - val_loss: 1.1828e-06 - val_acc: 0.9994
# Epoch 20/20
# 50/50 [==============================] - 128s 3s/step - loss: 0.0146 - acc: 0.9962 - val_loss: 0.0020 - val_acc: 0.9994

# %%
model.save('lung.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b-', label='Training acc')
plt.plot(epochs, val_acc, 'r-', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b-', label='Training loss')
plt.plot(epochs, val_loss, 'r-', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 18/18 [==============================] - 12s 651ms/step
# [2.6822095833267667e-07, 0.9981752038002014]

# %%
from keras.models import load_model

# %%
model_trained = load_model('/Users/yixuanwang/Desktop/2020 F Final_Project/lung.h5')
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model_trained

# %%
aaa=len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/A'))
bbb=len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/B'))
eee=len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/E'))
ggg=len(os.listdir('/Users/yixuanwang/Desktop/2020 F Final_Project/G'))

# %%
aaa
# Out:
# 375

# %%
bbb
# Out:
# 948

# %%
eee
# Out:
# 808

# %%
ggg
# Out:
# 608

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus'] = False

price = [aaa,bbb,eee,ggg]
"""
绘制水平条形图方法barh
参数一：y轴
参数二：x轴
"""
plt.barh(range(4), price, height=0.7, color='steelblue', alpha=0.8)      # 从下往上画
plt.yticks(range(5), ['A', 'B', 'E', 'G'])
# plt.xlim(30,47)
plt.xlabel("Number")
plt.title("Number of Each Class Lung Cancer")
for x, y in enumerate(price):
    plt.text(y + 0.2, x - 0.1, '%s' % y)
plt.show()

# %%
price
# Out:
# [375, 948, 808, 608]
